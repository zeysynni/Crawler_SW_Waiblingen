# %%
import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 82

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# wann ist die Hallenbadsaison?
# temporal
# Die Hallenbadsaison dauert vom 16. September bis zum 30. April. Die Freibadsaison läuft vom 1. Mai bis 15. September.
# ['Hallenbadsaison', '16. September', '30. April']

# %%
from collections import Counter

count = Counter([t.category for t in tests])
count
# Out:
# Counter({'procedural': 31,
#          'direct_fact': 21,
#          'spanning': 11,
#          'temporal': 9,
#          'numerical': 6,
#          'comparative': 2,
#          'relationship': 2})

# %%
from eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.25, ndcg=0.43067655807339306, keywords_found=3, total_keywords=3, keyword_coverage=100.0)

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# HOSTORY: []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 eval, answer, chunks = evaluate_answer(example)
#
# File ~/projects/agent_exercises/crawler copy/evaluation/eval.py:122, in evaluate_answer(test)
#     112 """
#     113 Evaluate answer quality using LLM-as-a-judge (async).
#     114
#    (...)    119     Tuple of (AnswerEval object, generated_answer string, retrieved_docs list)
#     120 """
#     121 # Get RAG response using shared answer module
# --> 122 generated_answer, retrieved_docs = answer_question(test.question)
#     124 # LLM judge prompt
#     125 judge_messages = [
#     126     {
#     127         "role": "system",
#    (...)    147     },
#     148 ]
#
# File ~/projects/agent_exercises/crawler copy/faq_bot/implementation/answer.py:52, in answer_question(question, history)
#      48 def answer_question(question: str, history: list[dict] = []) -> tuple[str, list[Document]]:
#      49     """
#      50     Answer the given question with RAG; return the answer and the context documents.
#      51     """
# ---> 52     combined = combined_question(question, history)
#      53     docs = fetch_context(combined) # consider all the prior questions when retrieving
#      54     context = "\n\n".join(doc.page_content for doc in docs)
#
# File ~/projects/agent_exercises/crawler copy/faq_bot/implementation/answer.py:45, in combined_question(question, history)
#      43 print(f"HOSTORY: {history}")
#      44 prior = "\n".join(m["content"][0]["text"] for m in history if m["role"] == "user")
# ---> 45 return prior + "\n" + question[-1]["text"]
#
# TypeError: string indices must be integers, not 'str'
